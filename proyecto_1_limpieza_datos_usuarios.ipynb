# %% [markdown]
# # Limpieza y Validación de Datos de Usuarios
#
# ## 📊 Descripción del Proyecto
#
# Este proyecto forma parte de una iniciativa de Store 1 para garantizar la coherencia en la recopilación de datos de usuarios. El objetivo es evaluar la calidad de los datos recopilados, identificar problemas en la estructura y formato, e implementar procesos de limpieza para preparar los datos para análisis posteriores.
#
# ## 🎯 Objetivo
#
# Desarrollar un proceso sistemático de limpieza de datos que:
# - Identifique inconsistencias en formato de nombres de usuario
# - Estandarice tipos de datos
# - Prepare datasets limpios para análisis de comportamiento de compra
#
# ## 📁 Dataset
#
# **Estructura de datos:**
# - **user_id**: Identificador único para cada usuario
# - **user_name**: Nombre del usuario
# - **user_age**: Edad del usuario
# - **fav_categories**: Categorías favoritas de artículos comprados
# - **total_spendings**: Lista de gastos totales por categoría
#
# **Tamaño del dataset**: 10 registros de usuarios
#
# ## 🛠️ Stack Técnico
#
# - Python 3.9
# - Métodos de strings: `strip()`, `replace()`, `split()`
# - Conversión de tipos de datos
# - Manipulación de listas

# %% [markdown]
# ## 1. Carga de Datos
#
# Importamos el dataset inicial con información de 10 usuarios.

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]],
]

# %% [markdown]
# ## 2. Análisis de Calidad de Datos
#
# ### Evaluación de un usuario ejemplo

# %%
user_id = '32415'
user_name = ' mike_reed '
user_age = 32.0
fav_categories = ['ELECTRONICS', 'SPORT', 'BOOKS']

# %% [markdown]
# ### Identificación de Problemas
#
# **Análisis de calidad de datos:**
#
# 1. **`user_id`**: Se mantiene como string. No requiere conversión a entero ya que funciona como identificador único sin operaciones aritméticas.
#
# 2. **`user_name`**: Presenta espacios en blanco innecesarios al inicio y final. Los guiones bajos son aceptables para nombres de usuario y no representan un problema.
#
# 3. **`user_age`**: Debe convertirse de float (32.0) a int (32), ya que la edad convencionalmente se representa con números enteros.
#
# 4. **`fav_categories`**: Mantener las categorías en mayúsculas es adecuado para estandarización y distinción clara de categorías.

# %% [markdown]
# ## 3. Implementación de Limpieza de Datos
#
# ### 3.1 Limpieza de Nombre de Usuario

# %%
user_name = ' mike_reed '

# Eliminar espacios y reemplazar guión bajo con espacio
user_name = user_name.strip().replace("_", " ")

print(user_name)

# %% [markdown]
# ### 3.2 División de Nombre Completo

# %%
user_name = 'mike reed'
name_split = user_name.split()

print(name_split)

# %% [markdown]
# ### 3.3 Conversión de Tipo de Dato de Edad

# %%
user_age = 32.0

# Convertir de float a int
user_age = int(user_age)

print(user_age)
print(type(user_age))

# %% [markdown]
# ## 4. Procesamiento Completo del Dataset
#
# ### Limpieza de múltiples usuarios

# %%
users = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
]

users_clean = []

# Procesar primer usuario
user_name_1 = users[0][1].strip().replace('_', ' ').split()
user_age_1 = int(users[0][2])
users_clean.append([users[0][0], user_name_1, user_age_1, users[0][3], users[0][4]])

# Procesar segundo usuario
user_name_2 = users[1][1].strip().replace('_', ' ').split()
user_age_2 = int(users[1][2])
users_clean.append([users[1][0], user_name_2, user_age_2, users[1][3], users[1][4]])

# Procesar tercer usuario
user_name_3 = users[2][1].strip().replace('_', ' ').split()
user_age_3 = int(users[2][2])
users_clean.append([users[2][0], user_name_3, user_age_3, users[2][3], users[2][4]])

print(users_clean)

# %% [markdown]
# ## 📈 Resultados
#
# **Transformaciones aplicadas:**
# - ✅ Eliminación de espacios en blanco innecesarios en nombres de usuario
# - ✅ Reemplazo de guiones bajos por espacios en nombres
# - ✅ División de nombres completos en componentes separados (nombre y apellido)
# - ✅ Conversión de edades de float a int
# - ✅ Preservación de formato de categorías en mayúsculas para estandarización
#
# **Datos limpios listos para:**
# - Análisis de comportamiento de compra
# - Segmentación de usuarios
# - Análisis de categorías favoritas
# - Estudios demográficos

# %% [markdown]
# ## 🔄 Próximos Pasos
#
# Este proceso de limpieza sienta las bases para:
# 1. Análisis exploratorio de datos (EDA)
# 2. Segmentación de clientes por edad y preferencias
# 3. Análisis de patrones de gasto por categoría
# 4. Desarrollo de modelos predictivos de comportamiento de compra
